# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistics = mp.solutions.holistic # holistic Model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_styled_landmarks(image, model):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistics.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(80,110,10),thickness=1, circle_radius=1),
                                mp_drawing.DrawingSpec(color=(80,256,121),thickness=1, circle_radius=1)
                                )
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistics.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistics.HAND_CONNECTIONS)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
actions = np.array(['hello', 'iloveyou', 'bench','thanks','cloud', 'come here', 'congratulations','blender','how'])

directory = "Final_Data"
no_of_sequences = 50
sequence_length =  30

# %%
data_path = os.path.join(directory)
for action in actions: 
    for sequence in range(no_of_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
 label_map = {label:num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_of_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(data_path, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
x = np.array(sequences)
y = to_categorical(labels).astype(int)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(x_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000269BF6AB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000269BF6AB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 14/14 [==============================] - 10s 107ms/step - loss: 2.1025 - categorical_accuracy: 0.2365
# Epoch 2/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 1.8151 - categorical_accuracy: 0.3864
# Epoch 3/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 1.2154 - categorical_accuracy: 0.5808
# Epoch 4/2000
# 14/14 [==============================] - 1s 107ms/step - loss: 1.2111 - categorical_accuracy: 0.6089
# Epoch 5/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.8916 - categorical_accuracy: 0.6745
# Epoch 6/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.7536 - categorical_accuracy: 0.7166
# Epoch 7/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 1.1044 - categorical_accuracy: 0.6745
# Epoch 8/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.8592 - categorical_accuracy: 0.6862
# Epoch 9/2000
# 14/14 [==============================] - 1s 105ms/step - loss: 0.5002 - categorical_accuracy: 0.8197
# Epoch 10/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.5063 - categorical_accuracy: 0.8197
# Epoch 11/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 0.4105 - categorical_accuracy: 0.8548
# Epoch 12/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3371 - categorical_accuracy: 0.8712
# Epoch 13/2000
# 14/14 [==============================] - 1s 104ms/step - loss: 0.2878 - categorical_accuracy: 0.8829
# Epoch 14/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3408 - categorical_accuracy: 0.8782
# Epoch 15/2000
# 14/14 [==============================] - 2s 112ms/step - loss: 1.2279 - categorical_accuracy: 0.8689
# Epoch 16/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.6580 - categorical_accuracy: 0.7963
# Epoch 17/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.4298 - categorical_accuracy: 0.8571
# Epoch 18/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.3173 - categorical_accuracy: 0.8993
# Epoch 19/2000
# 14/14 [==============================] - 1s 107ms/step - loss: 0.9709 - categorical_accuracy: 0.7354
# Epoch 20/2000
# 14/14 [==============================] - 2s 108ms/step - loss: 0.5440 - categorical_accuracy: 0.8314
# Epoch 21/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.3338 - categorical_accuracy: 0.8806
# Epoch 22/2000
# 14/14 [==============================] - 2s 109ms/step - loss: 0.4145 - categorical_accuracy: 0.8571
# Epoch 23/2000
# 14/14 [==============================] - 1s 104ms/step - loss: 0.2619 - categorical_accuracy: 0.9133
# Epoch 24/2000
# 14/14 [==============================] - 1s 106ms/step - loss: 0.2420 - categorical_accuracy: 0.9110
# Epoch 25/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.2372 - categorical_accuracy: 0.9157
# Epoch 26/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.1920 - categorical_accuracy: 0.9274
# Epoch 27/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.1929 - categorical_accuracy: 0.9180
# Epoch 28/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.3277 - categorical_accuracy: 0.9016
# Epoch 29/2000
# 14/14 [==============================] - 1s 91ms/step - loss: 0.2583 - categorical_accuracy: 0.9180
# Epoch 30/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.3241 - categorical_accuracy: 0.8899
# Epoch 31/2000
# 14/14 [==============================] - 1s 103ms/step - loss: 0.1961 - categorical_accuracy: 0.9368
# Epoch 32/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1627 - categorical_accuracy: 0.9461
# Epoch 33/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1769 - categorical_accuracy: 0.9391
# Epoch 34/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.2504 - categorical_accuracy: 0.9110
# Epoch 35/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1822 - categorical_accuracy: 0.9391
# Epoch 36/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1317 - categorical_accuracy: 0.9461
# Epoch 37/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1555 - categorical_accuracy: 0.9415
# Epoch 38/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1402 - categorical_accuracy: 0.9485
# Epoch 39/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1678 - categorical_accuracy: 0.9461
# Epoch 40/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.1169 - categorical_accuracy: 0.9532
# Epoch 41/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0972 - categorical_accuracy: 0.9602
# Epoch 42/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.2022 - categorical_accuracy: 0.9297
# Epoch 43/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1587 - categorical_accuracy: 0.9438
# Epoch 44/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1487 - categorical_accuracy: 0.9485
# Epoch 45/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 0.1729 - categorical_accuracy: 0.9321
# Epoch 46/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1515 - categorical_accuracy: 0.9461
# Epoch 47/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1177 - categorical_accuracy: 0.9649
# Epoch 48/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0811 - categorical_accuracy: 0.9719
# Epoch 49/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0699 - categorical_accuracy: 0.9672
# Epoch 50/2000
# 14/14 [==============================] - 1s 103ms/step - loss: 0.1295 - categorical_accuracy: 0.9485
# Epoch 51/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1091 - categorical_accuracy: 0.9578
# Epoch 52/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.1324 - categorical_accuracy: 0.9368
# Epoch 53/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0962 - categorical_accuracy: 0.9672
# Epoch 54/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1336 - categorical_accuracy: 0.9415
# Epoch 55/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0965 - categorical_accuracy: 0.9532
# Epoch 56/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.1663 - categorical_accuracy: 0.9368
# Epoch 57/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1303 - categorical_accuracy: 0.9485
# Epoch 58/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1003 - categorical_accuracy: 0.9625
# Epoch 59/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.2294 - categorical_accuracy: 0.9321
# Epoch 60/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.4073 - categorical_accuracy: 0.8571
# Epoch 61/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.5022 - categorical_accuracy: 0.8431
# Epoch 62/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.2423 - categorical_accuracy: 0.9251
# Epoch 63/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.5674 - categorical_accuracy: 0.8829
# Epoch 64/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 1.0884 - categorical_accuracy: 0.6230
# Epoch 65/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.4300 - categorical_accuracy: 0.8899
# Epoch 66/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.2257 - categorical_accuracy: 0.9227
# Epoch 67/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1549 - categorical_accuracy: 0.9415
# Epoch 68/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 0.1153 - categorical_accuracy: 0.9578
# Epoch 69/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1202 - categorical_accuracy: 0.9508
# Epoch 70/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1442 - categorical_accuracy: 0.9578
# Epoch 71/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1085 - categorical_accuracy: 0.9649
# Epoch 72/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0895 - categorical_accuracy: 0.9696
# Epoch 73/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0856 - categorical_accuracy: 0.9672
# Epoch 74/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0885 - categorical_accuracy: 0.9672
# Epoch 75/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0894 - categorical_accuracy: 0.9696
# Epoch 76/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0732 - categorical_accuracy: 0.9696
# Epoch 77/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0674 - categorical_accuracy: 0.9672
# Epoch 78/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.2766 - categorical_accuracy: 0.9485
# Epoch 79/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1769 - categorical_accuracy: 0.9461
# Epoch 80/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1573 - categorical_accuracy: 0.9485
# Epoch 81/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1150 - categorical_accuracy: 0.9649
# Epoch 82/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1007 - categorical_accuracy: 0.9602
# Epoch 83/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.1161 - categorical_accuracy: 0.9602
# Epoch 84/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0897 - categorical_accuracy: 0.9672
# Epoch 85/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.4517 - categorical_accuracy: 0.8829
# Epoch 86/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.4967 - categorical_accuracy: 0.8173
# Epoch 87/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3978 - categorical_accuracy: 0.8431
# Epoch 88/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.2869 - categorical_accuracy: 0.8712
# Epoch 89/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.2010 - categorical_accuracy: 0.9532
# Epoch 90/2000
# 14/14 [==============================] - 1s 102ms/step - loss: 0.1387 - categorical_accuracy: 0.9602
# Epoch 91/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1301 - categorical_accuracy: 0.9555
# Epoch 92/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1430 - categorical_accuracy: 0.9461
# Epoch 93/2000
# 14/14 [==============================] - 1s 102ms/step - loss: 0.2039 - categorical_accuracy: 0.9485
# Epoch 94/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.2033 - categorical_accuracy: 0.9274
# Epoch 95/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1423 - categorical_accuracy: 0.9555
# Epoch 96/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1334 - categorical_accuracy: 0.9485
# Epoch 97/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3929 - categorical_accuracy: 0.9344
# Epoch 98/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.1936 - categorical_accuracy: 0.9508
# Epoch 99/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.1665 - categorical_accuracy: 0.9461
# Epoch 100/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1104 - categorical_accuracy: 0.9649
# Epoch 101/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1297 - categorical_accuracy: 0.9555
# Epoch 102/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1068 - categorical_accuracy: 0.9602
# Epoch 103/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0967 - categorical_accuracy: 0.9625
# Epoch 104/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0924 - categorical_accuracy: 0.9649
# Epoch 105/2000
# 14/14 [==============================] - 1s 91ms/step - loss: 0.1099 - categorical_accuracy: 0.9555
# Epoch 106/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1037 - categorical_accuracy: 0.9649
# Epoch 107/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0867 - categorical_accuracy: 0.9696
# Epoch 108/2000
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0748 - categorical_accuracy: 0.9742
# Epoch 109/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0719 - categorical_accuracy: 0.9789
# Epoch 110/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0700 - categorical_accuracy: 0.9766
# Epoch 111/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0651 - categorical_accuracy: 0.9696
# Epoch 112/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0652 - categorical_accuracy: 0.9742
# Epoch 113/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0589 - categorical_accuracy: 0.9789
# Epoch 114/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0682 - categorical_accuracy: 0.9742
# Epoch 115/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0646 - categorical_accuracy: 0.9789
# Epoch 116/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0946 - categorical_accuracy: 0.9696
# Epoch 117/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.4590 - categorical_accuracy: 0.9110
# Epoch 118/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.3300 - categorical_accuracy: 0.8759
# Epoch 119/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1810 - categorical_accuracy: 0.9461
# Epoch 120/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1727 - categorical_accuracy: 0.9415
# Epoch 121/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1782 - categorical_accuracy: 0.9321
# Epoch 122/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0909 - categorical_accuracy: 0.9719
# Epoch 123/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0723 - categorical_accuracy: 0.9696
# Epoch 124/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0639 - categorical_accuracy: 0.9766
# Epoch 125/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0662 - categorical_accuracy: 0.9719
# Epoch 126/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1078 - categorical_accuracy: 0.9602
# Epoch 127/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0952 - categorical_accuracy: 0.9625
# Epoch 128/2000
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0747 - categorical_accuracy: 0.9696
# Epoch 129/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0641 - categorical_accuracy: 0.9766
# Epoch 130/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0617 - categorical_accuracy: 0.9742
# Epoch 131/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0457 - categorical_accuracy: 0.9813
# Epoch 132/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0459 - categorical_accuracy: 0.9813
# Epoch 133/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0593 - categorical_accuracy: 0.9742
# Epoch 134/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0498 - categorical_accuracy: 0.9813
# Epoch 135/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0528 - categorical_accuracy: 0.9766
# Epoch 136/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0451 - categorical_accuracy: 0.9789
# Epoch 137/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0383 - categorical_accuracy: 0.9789
# Epoch 138/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0363 - categorical_accuracy: 0.9813
# Epoch 139/2000
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0310 - categorical_accuracy: 0.9836
# Epoch 140/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0302 - categorical_accuracy: 0.9836
# Epoch 141/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0612 - categorical_accuracy: 0.9766
# Epoch 142/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0535 - categorical_accuracy: 0.9813
# Epoch 143/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0572 - categorical_accuracy: 0.9742
# Epoch 144/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0622 - categorical_accuracy: 0.9742
# Epoch 145/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0684 - categorical_accuracy: 0.9742
# Epoch 146/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0383 - categorical_accuracy: 0.9836
# Epoch 147/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0437 - categorical_accuracy: 0.9813
# Epoch 148/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.2087 - categorical_accuracy: 0.9274
# Epoch 149/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1836 - categorical_accuracy: 0.9391
# Epoch 150/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0922 - categorical_accuracy: 0.9696
# Epoch 151/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.1198 - categorical_accuracy: 0.9532
# Epoch 152/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1313 - categorical_accuracy: 0.9602
# Epoch 153/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0605 - categorical_accuracy: 0.9719
# Epoch 154/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0608 - categorical_accuracy: 0.9766
# Epoch 155/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0590 - categorical_accuracy: 0.9742
# Epoch 156/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 2.6019 - categorical_accuracy: 0.8946
# Epoch 157/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 1.0558 - categorical_accuracy: 0.6511
# Epoch 158/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 1.1316 - categorical_accuracy: 0.5948
# Epoch 159/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.8080 - categorical_accuracy: 0.7447
# Epoch 160/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.4579 - categorical_accuracy: 0.8712
# Epoch 161/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.3292 - categorical_accuracy: 0.9180
# Epoch 162/2000
# 14/14 [==============================] - 1s 91ms/step - loss: 0.2493 - categorical_accuracy: 0.9344
# Epoch 163/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1820 - categorical_accuracy: 0.9415
# Epoch 164/2000
# 14/14 [==============================] - 1s 92ms/step - loss: 0.1346 - categorical_accuracy: 0.9508
# Epoch 165/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.1413 - categorical_accuracy: 0.9508
# Epoch 166/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1109 - categorical_accuracy: 0.9602
# Epoch 167/2000
# 14/14 [==============================] - 1s 106ms/step - loss: 0.1260 - categorical_accuracy: 0.9532
# Epoch 168/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.2342 - categorical_accuracy: 0.9602
# Epoch 169/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1557 - categorical_accuracy: 0.9532
# Epoch 170/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.1071 - categorical_accuracy: 0.9578
# Epoch 171/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0886 - categorical_accuracy: 0.9672
# Epoch 172/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1496 - categorical_accuracy: 0.9508
# Epoch 173/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0975 - categorical_accuracy: 0.9602
# Epoch 174/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0735 - categorical_accuracy: 0.9696
# Epoch 175/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0641 - categorical_accuracy: 0.9719
# Epoch 176/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0729 - categorical_accuracy: 0.9742
# Epoch 177/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.1030 - categorical_accuracy: 0.9508
# Epoch 178/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0727 - categorical_accuracy: 0.9766
# Epoch 179/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0712 - categorical_accuracy: 0.9766
# Epoch 180/2000
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0709 - categorical_accuracy: 0.9789
# Epoch 181/2000
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0455 - categorical_accuracy: 0.9789
# Epoch 182/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0402 - categorical_accuracy: 0.9813
# Epoch 183/2000
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0329 - categorical_accuracy: 0.9859
# Epoch 184/2000
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0412 - categorical_accuracy: 0.9836
# Epoch 185/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0490 - categorical_accuracy: 0.9813
# Epoch 186/2000
# 14/14 [==============================] - 1s 107ms/step - loss: 0.0741 - categorical_accuracy: 0.9766
# Epoch 187/2000
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0924 - categorical_accuracy: 0.9672
# Epoch 188/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0847 - categorical_accuracy: 0.9625
# Epoch 189/2000
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0720 - categorical_accuracy: 0.9719
# Epoch 190/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0568 - categorical_accuracy: 0.9789
# Epoch 191/2000
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0498 - categorical_accuracy: 0.9813
# Epoch 192/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.1020 - categorical_accuracy: 0.9578
# Epoch 193/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1010 - categorical_accuracy: 0.9672
# Epoch 194/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0640 - categorical_accuracy: 0.9766
# Epoch 195/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0543 - categorical_accuracy: 0.9719
# Epoch 196/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0385 - categorical_accuracy: 0.9813
# Epoch 197/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0360 - categorical_accuracy: 0.9836
# Epoch 198/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0456 - categorical_accuracy: 0.9766
# Epoch 199/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.1076 - categorical_accuracy: 0.9602
# Epoch 200/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0905 - categorical_accuracy: 0.9649
# Epoch 201/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0554 - categorical_accuracy: 0.9836
# Epoch 202/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.1795 - categorical_accuracy: 0.9532
# Epoch 203/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0687 - categorical_accuracy: 0.9742
# Epoch 204/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0716 - categorical_accuracy: 0.9696
# Epoch 205/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0577 - categorical_accuracy: 0.9696
# Epoch 206/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0745 - categorical_accuracy: 0.9555
# Epoch 207/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0521 - categorical_accuracy: 0.9742
# Epoch 208/2000
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0417 - categorical_accuracy: 0.9836
# Epoch 209/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0445 - categorical_accuracy: 0.9813
# Epoch 210/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0431 - categorical_accuracy: 0.9742
# Epoch 211/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0452 - categorical_accuracy: 0.9813
# Epoch 212/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0304 - categorical_accuracy: 0.9859
# Epoch 213/2000
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0266 - categorical_accuracy: 0.9883
# Epoch 214/2000
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0234 - categorical_accuracy: 0.9906
# Epoch 215/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0182 - categorical_accuracy: 0.9930
# Epoch 216/2000
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0180 - categorical_accuracy: 0.9906
# Epoch 217/2000
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0171 - categorical_accuracy: 0.9906
# Epoch 218/2000
# 14/14 [==============================] - 1s 104ms/step - loss: 0.1401 - categorical_accuracy: 0.9532
# Epoch 219/2000
# 14/14 [==============================] - 1s 99ms/step - loss: 10977.3994 - categorical_accuracy: 0.6066
# Epoch 220/2000
# 14/14 [==============================] - 1s 95ms/step - loss: 2.9082 - categorical_accuracy: 0.2061
# Epoch 221/2000
# 14/14 [==============================] - 1s 96ms/step - loss: 1.7538 - categorical_accuracy: 0.3162
# Epoch 222/2000
# 14/14 [==============================] - 1s 104ms/step - loss: 1.3990 - categorical_accuracy: 0.4309
# Epoch 223/2000
# 14/14 [==============================] - 1s 107ms/step - loss: 1.1965 - categorical_accuracy: 0.4965
# Epoch 224/2000
# 14/14 [==============================] - 1s 101ms/step - loss: 0.8552 - categorical_accuracy: 0.6253
# Epoch 225/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4136/1143689619.py in <module>
#       1 model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# ----> 2 model.fit(x_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# c:\Users\HP\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            82688
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 9)                 297
#
# =================================================================
# Total params: 237,449
# Trainable params: 237,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(x_test)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000269CC344DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000269CC344DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 1s 835ms/step

# %%
model.save('final.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(x_train)
ytrue = np.argmax(y_train, axis =1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
# Out:
# 14/14 [==============================] - 1s 35ms/step

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[374,   4],
#         [  0,  49]],
#
#        [[378,   1],
#         [  5,  43]],
#
#        [[379,   1],
#         [  2,  45]],
#
#        [[317,  61],
#         [  8,  41]],
#
#        [[374,   6],
#         [ 12,  35]],
#
#        [[371,  10],
#         [ 29,  17]],
#
#        [[376,   2],
#         [  8,  41]],
#
#        [[356,  25],
#         [  0,  46]],
#
#        [[381,   0],
#         [ 46,   0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.7423887587822015

# %%
colors = [(245, 117, 16), (117,245,16), (16, 117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame

# %%
res = model.predict(np.expand_dims(sequence, axis=0))[0]
np.argmax(res)

# %%
# 1. New Detection variables
sequence = []
sentence = []
#predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0) # accessing webcam zero
# Set MediaPipe model
with mp_holistics.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():      # while the webcam is accessed
    
            #read feed
            ret, frame = cap.read()    # we are reading the frame

            # MaKE dETECTIONS
            image, results = mediapipe_detection(frame, holistic)
            print(results)  
            
            #Draw Landmarks
            draw_styled_landmarks(image, results)
            
            # 2. Prediction logic
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]
            
            if len(sequence) == 30:
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                #predictions.append(np.argmax(res))
                
            # 3. Viz logic
            #if np.unique(predictions[-10:])[0]==np.argmax(res):
            if res[np.argmax(res)] > threshold:
                if len(sentence) > 0:
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])
                        
            if len(sentence) > 5:
                sentence = sentence[-5:]
                
            # Viz Probability
            #image = prob_viz(res, actions, image, colors)
                
            cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
            cv2.putText(image, ' '.join(sentence), (3,30),
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            #Show to Screen
            cv2.imshow('Live Feed', image) # then showing to the user

            # Breaking Gracefully by pressing q
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# cloud
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# blender
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# come here
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks

# %%
    cap.release()
    cv2.destroyAllWindows()

# %%
res = model.predict(np.expand_dims(sequence, axis=0))[0]
# Out:
# 1/1 [==============================] - 1s 947ms/step

# %%
np.argmax(res)
# Out:
# 4
